# %%
import pandas as pd

# %%
train_split = pd.read_csv('train_split.csv')

# %%
df = pd.read_csv('gx_merged.csv')

# %%
 pd.merge(df, train_split,how='left',left_on=['country','brand'], right_on = ['country','brand'])
# Out:
#          country      brand     volume  month_num month_name  test  \
# 0      country_1    brand_3  7695813.6          0        Nov     0
# 1      country_1    brand_3  7975224.0          1        Dec     0
# 2      country_1    brand_3  5796840.6          2        Jan     0
# 3      country_1    brand_3  4895233.2          3        Feb     0
# 4      country_1    brand_3  6053583.6          4        Mar     0
# ...          ...        ...        ...        ...        ...   ...
# 25307  country_9  brand_187        NaN         19        NaN     1
# 25308  country_9  brand_187        NaN         20        NaN     1
# 25309  country_9  brand_187        NaN         21        NaN     1
# 25310  country_9  brand_187        NaN         22        NaN     1
# 25311  country_9  brand_187        NaN         23        NaN     1
#
#        num_generics               therapeutic_area presentation           B  \
# 0                 3       Cardiovascular_Metabolic         PILL    1.189704
# ...
